# %% [markdown]
# # Time Series Decomposition

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
df = pd.read_csv('AirPassengers.csv', index_col='Month', parse_dates=True)
df
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# ...                 ...
# 1960-08-01          606
# 1960-09-01          508
# 1960-10-01          461
# 1960-11-01          390
# 1960-12-01          432
#
# [144 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 1949-01-01 to 1960-12-01
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   #Passengers  144 non-null    int64
# dtypes: int64(1)
# memory usage: 2.2 KB

# %%
df.isna().sum()
# Out:
# #Passengers    0
# dtype: int64

# %%
df.columns = ['nPass']

# %%
df.head()
# Out:
#             nPass
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121

# %% [markdown]
# ### Visualize the time series data

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(12, 6))
plt.plot(df['nPass'])
plt.xlabel('Months')
plt.ylabel('Number of Air Passengers')
plt.title('Air Passengers 1949-1960')
plt.grid()
plt.show()

# %% [markdown]
# ### Time series decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
Q = seasonal_decompose(df['nPass'], model='multiplicative')

# %%
Q.plot()

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(12, 6))
plt.plot(df['nPass'], label='orignal')
plt.plot(Q.trend, label='Trend')
plt.xlabel('Months')
plt.ylabel('Number of Air Passengers')
plt.title('Air Passengers 1949-1960')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(Q.seasonal)
plt.xlabel('Month')
plt.ylabel('Seasonality')
plt.title('Seasonality Plot')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(Q.resid)
plt.xlabel('Month')
plt.ylabel('Residual')
plt.title('Residual Plot')
plt.show()

# %% [markdown]
# Multiplicative model yt = Trend X Season X Residual

# %% [markdown]
# ### Time Series Forecasting

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ARIMA - Auto Regression Integrated Moving Average

# %% [markdown]
# ### Install the pmdarima model

# %%
# %pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from pmdarima) (3.0.8)
# Requirement already satisfied: numpy>=1.21.2 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from pmdarima) (1.26.2)
# Requirement already satisfied: pandas>=0.19 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from pmdarima) (2.1.3)
# Requirement already satisfied: scikit-learn>=0.22 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: scipy>=1.3.2 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from pmdarima) (1.11.4)
# Requirement already satisfied: statsmodels>=0.13.2 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from pmdarima) (2.1.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from pmdarima) (65.5.0)
# Requirement already satisfied: packaging>=17.1 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from pmdarima) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in e:\wakad thu fri 6 8 pm\repository\venv\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Restart the kernel and run all cells

# %%
from pmdarima.arima import auto_arima

# %%
model = auto_arima(df['nPass'], seasonal=True, m=12)

# %%
model.order
# Out:
# (2, 1, 1)

# %%
p = model.order[0]
d = model.order[1]
q = model.order[2]

# %%
p
# Out:
# 2

# %%
d
# Out:
# 1

# %%
q
# Out:
# 1

# %% [markdown]
# ### Get the forecasted value for next 3 years
# 3 years - 12*3 = 36 months

# %%
forecast, conf = model.predict(n_periods=36, return_conf_int=True)

# %%
forecast
# Out:
# 1961-01-01    445.634934
# 1961-02-01    420.395042
# 1961-03-01    449.198378
# 1961-04-01    491.840023
# 1961-05-01    503.394565
# 1961-06-01    566.862550
# 1961-07-01    654.260284
# 1961-08-01    638.597604
# 1961-09-01    540.883864
# 1961-10-01    494.126748
# 1961-11-01    423.332841
# 1961-12-01    465.507712
# 1962-01-01    479.291026
# 1962-02-01    454.177037
# 1962-03-01    483.087203
# 1962-04-01    525.819493
# 1962-05-01    537.450950
# 1962-06-01    600.984197
# 1962-07-01    688.437307
# 1962-08-01    672.821614
# 1962-09-01    575.147743
# 1962-10-01    528.424456
# 1962-11-01    457.659254
# 1962-12-01    499.858481
# 1963-01-01    513.662462
# 1963-02-01    488.566008
# 1963-03-01    517.491053
# 1963-04-01    560.235969
# 1963-05-01    571.878138
# 1963-06-01    635.420475
# 1963-07-01    722.881298
# 1963-08-01    707.272149
# 1963-09-01    609.603831
# 1963-10-01    562.885256
# 1963-11-01    492.124052
# 1963-12-01    534.326671
# Freq: MS, dtype: float64

# %%
conf
# Out:
# array([[423.34475094, 467.92511658],
#        [394.23518302, 446.55490116],
#        [419.83140846, 478.56534829],
#        [460.37587373, 523.30417201],
#        [470.37999658, 536.40913406],
#        [532.69880168, 601.02629843],
#        [619.22055901, 689.30000963],
#        [602.87921604, 674.31599104],
#        [504.63055231, 577.13717502],
#        [457.44514984, 530.80834643],
#        [386.3030106 , 460.36267117],
#        [428.19044593, 502.82497842],
#        [433.49653884, 525.08551376],
#        [405.10774907, 503.24632483],
#        [431.15437638, 535.02002912],
#        [471.83916844, 579.79981805],
#        [481.87209035, 593.02980929],
#        [544.15500525, 657.81338881],
#        [630.60709073, 746.26752372],
#        [614.17741433, 731.46581272],
#        [515.83056926, 634.46491613],
#        [468.54219966, 588.30671331],
#        [397.2952923 , 518.02321528],
#        [439.07790127, 560.63906114],
#        [446.32509131, 580.99983223],
#        [418.31603539, 558.81598086],
#        [444.62194643, 590.36015987],
#        [485.39943994, 635.07249774],
#        [495.4479624 , 648.30831366],
#        [557.69634351, 713.1446065 ],
#        [644.08397085, 801.67862509],
#        [627.57137805, 786.97291922],
#        [529.13050031, 690.07716124],
#        [481.74160891, 644.02890374],
#        [410.39065083, 573.85745237],
#        [452.0675645 , 616.58577818]])

# %% [markdown]
# ### Add above results in dataframe

# %%
df_forecast = forecast.to_frame()
df_forecast.columns = ['forecast']
df_forecast
# Out:
#               forecast
# 1961-01-01  445.634934
# 1961-02-01  420.395042
# 1961-03-01  449.198378
# 1961-04-01  491.840023
# 1961-05-01  503.394565
# 1961-06-01  566.862550
# 1961-07-01  654.260284
# 1961-08-01  638.597604
# 1961-09-01  540.883864
# 1961-10-01  494.126748
# 1961-11-01  423.332841
# 1961-12-01  465.507712
# 1962-01-01  479.291026
# 1962-02-01  454.177037
# 1962-03-01  483.087203
# 1962-04-01  525.819493
# 1962-05-01  537.450950
# 1962-06-01  600.984197
# 1962-07-01  688.437307
# 1962-08-01  672.821614
# 1962-09-01  575.147743
# 1962-10-01  528.424456
# 1962-11-01  457.659254
# 1962-12-01  499.858481
# 1963-01-01  513.662462
# 1963-02-01  488.566008
# 1963-03-01  517.491053
# 1963-04-01  560.235969
# 1963-05-01  571.878138
# 1963-06-01  635.420475
# 1963-07-01  722.881298
# 1963-08-01  707.272149
# 1963-09-01  609.603831
# 1963-10-01  562.885256
# 1963-11-01  492.124052
# 1963-12-01  534.326671

# %%
df_forecast[['Low_conf', 'Upper_conf']] = conf

# %%
df_forecast
# Out:
#               forecast    Low_conf  Upper_conf
# 1961-01-01  445.634934  423.344751  467.925117
# 1961-02-01  420.395042  394.235183  446.554901
# 1961-03-01  449.198378  419.831408  478.565348
# 1961-04-01  491.840023  460.375874  523.304172
# 1961-05-01  503.394565  470.379997  536.409134
# 1961-06-01  566.862550  532.698802  601.026298
# 1961-07-01  654.260284  619.220559  689.300010
# 1961-08-01  638.597604  602.879216  674.315991
# 1961-09-01  540.883864  504.630552  577.137175
# 1961-10-01  494.126748  457.445150  530.808346
# 1961-11-01  423.332841  386.303011  460.362671
# 1961-12-01  465.507712  428.190446  502.824978
# 1962-01-01  479.291026  433.496539  525.085514
# 1962-02-01  454.177037  405.107749  503.246325
# 1962-03-01  483.087203  431.154376  535.020029
# 1962-04-01  525.819493  471.839168  579.799818
# 1962-05-01  537.450950  481.872090  593.029809
# 1962-06-01  600.984197  544.155005  657.813389
# 1962-07-01  688.437307  630.607091  746.267524
# 1962-08-01  672.821614  614.177414  731.465813
# 1962-09-01  575.147743  515.830569  634.464916
# 1962-10-01  528.424456  468.542200  588.306713
# 1962-11-01  457.659254  397.295292  518.023215
# 1962-12-01  499.858481  439.077901  560.639061
# 1963-01-01  513.662462  446.325091  580.999832
# 1963-02-01  488.566008  418.316035  558.815981
# 1963-03-01  517.491053  444.621946  590.360160
# 1963-04-01  560.235969  485.399440  635.072498
# 1963-05-01  571.878138  495.447962  648.308314
# 1963-06-01  635.420475  557.696344  713.144607
# 1963-07-01  722.881298  644.083971  801.678625
# 1963-08-01  707.272149  627.571378  786.972919
# 1963-09-01  609.603831  529.130500  690.077161
# 1963-10-01  562.885256  481.741609  644.028904
# 1963-11-01  492.124052  410.390651  573.857452
# 1963-12-01  534.326671  452.067565  616.585778

# %%
df_forecast['forecast'] = df_forecast['forecast'].apply(round)

# %%
df_forecast.head()
# Out:
#             forecast    Low_conf  Upper_conf
# 1961-01-01       446  423.344751  467.925117
# 1961-02-01       420  394.235183  446.554901
# 1961-03-01       449  419.831408  478.565348
# 1961-04-01       492  460.375874  523.304172
# 1961-05-01       503  470.379997  536.409134

# %%
for i in df_forecast.columns:
    df_forecast[i] = df_forecast[i].apply(round)

# %%
df_forecast
# Out:
#             forecast  Low_conf  Upper_conf
# 1961-01-01       446       423         468
# 1961-02-01       420       394         447
# 1961-03-01       449       420         479
# 1961-04-01       492       460         523
# 1961-05-01       503       470         536
# 1961-06-01       567       533         601
# 1961-07-01       654       619         689
# 1961-08-01       639       603         674
# 1961-09-01       541       505         577
# 1961-10-01       494       457         531
# 1961-11-01       423       386         460
# 1961-12-01       466       428         503
# 1962-01-01       479       433         525
# 1962-02-01       454       405         503
# 1962-03-01       483       431         535
# 1962-04-01       526       472         580
# 1962-05-01       537       482         593
# 1962-06-01       601       544         658
# 1962-07-01       688       631         746
# 1962-08-01       673       614         731
# 1962-09-01       575       516         634
# 1962-10-01       528       469         588
# 1962-11-01       458       397         518
# 1962-12-01       500       439         561
# 1963-01-01       514       446         581
# 1963-02-01       489       418         559
# 1963-03-01       517       445         590
# 1963-04-01       560       485         635
# 1963-05-01       572       495         648
# 1963-06-01       635       558         713
# 1963-07-01       723       644         802
# 1963-08-01       707       628         787
# 1963-09-01       610       529         690
# 1963-10-01       563       482         644
# 1963-11-01       492       410         574
# 1963-12-01       534       452         617

# %% [markdown]
# ### Save above dataframe to csv

# %%
df_forecast.to_csv('AirPassengerForecast.csv')

# %% [markdown]
# ### Visualizing above results

# %%
plt.figure(figsize=(12,6))
plt.plot(df['nPass'], label='Observed')
plt.plot(df_forecast['forecast'], label='Forecast')
plt.fill_between(df_forecast.index, df_forecast['Low_conf'], df_forecast['Upper_conf'], color='gray', label='confidence interval')
plt.xlabel('Month')
plt.ylabel('Number of Air Passengers')
plt.title('Forecasted Values')
plt.legend()
plt.show()
